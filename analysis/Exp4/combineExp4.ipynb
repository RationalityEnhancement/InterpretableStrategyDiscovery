# %%
import pandas as pd

pd.set_option('display.max_rows', 181)
pd.set_option('display.max_columns', 80)
pd.set_option('display.max_colwidth', 60)

# %%
# import
if(True):
    df_inc = pd.read_csv('data/Exp4A/dataframe_complete.csv')
    df_inc['pid'] = df_inc['pid']+100
    df_inc.insert(2, 'structure', 'increasing')

    df_dec = pd.read_csv('data/Exp4B/dataframe_complete.csv')
    df_dec['pid'] = df_dec['pid']+200
    df_dec.insert(2, 'structure', 'decreasing')

    df_con = pd.read_csv('data/Exp4C/dataframe_complete.csv')
    df_con['pid'] = df_con['pid']+300
    df_con.insert(2, 'structure', 'constant')

    dataframe = pd.concat([df_inc, df_dec, df_con])
    dataframe.to_csv('data/EXP4/dataframe_complete.csv', index=False)
else: 
    dataframe = pd.read_csv('data/Exp4/dataframe_complete.csv')

# %%
dataframe
# Out:
#      pid  condition   structure  condition_type                    beginHit  \
# 0    100          0  increasing       flowchart  2020-09-23 16:17:06.722939
# 1    101          0  increasing       flowchart  2020-09-23 16:07:04.273675
# 2    102          0  increasing       flowchart  2020-09-23 16:11:43.659499
# 3    103          0  increasing       flowchart  2020-09-23 16:07:22.506077
# 4    104          0  increasing       flowchart  2020-09-23 16:07:05.716785
# ..   ...        ...         ...             ...                         ...
# 158  458          1    constant  actionfeedback  2020-09-30 23:27:55.688023
# 159  459          1    constant  actionfeedback  2020-09-30 23:24:23.819587
# 160  460          1    constant  actionfeedback   2020-09-30 23:26:59.43174
# 161  461          1    constant  actionfeedback  2020-09-30 23:06:05.103414
# 162  462          1    constant  actionfeedback  2020-09-30 22:16:52.045835
#
# ...
